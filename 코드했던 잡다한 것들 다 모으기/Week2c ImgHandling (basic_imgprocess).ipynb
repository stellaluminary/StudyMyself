# %%
import numpy as np
import os
from scipy.misc import imread, imresize
import matplotlib.pyplot as plt
# %matplotlib inline
print('package Loaded')
# Out:
# package Loaded

# %%
cwd=os.getcwd()
print('Current folder is %s' %(cwd))
# Out:
# Current folder is C:\Users\la

# %%
def print_typeshape(img):
    print('Type is %s'%(type(img)))
    print('Shape is %s'%(img.shape,))

# %%
cat=imread('./data/cat.jpg')
cat.shape
# Out:
# (368, 700, 3)

# %%
print_typeshape(cat)
# Out:
# Type is <class 'numpy.ndarray'>
# Shape is (368, 700, 3)

# %%
plt.figure(figsize=(10,8))
plt.imshow(cat)
plt.draw()

# %%
cat2=imread('./data/cat.jpg').astype(np.float)
print_typeshape(cat2)
# Out:
# Type is <class 'numpy.ndarray'>
# Shape is (368, 700, 3)

# %%
cat3=imread('./data/cat.jpg').astype(np.float)
print_typeshape(cat3)
plt.figure(figsize=(10,8))
plt.imshow(cat3/255.)
plt.draw()
# Out:
# Type is <class 'numpy.ndarray'>
# Shape is (368, 700, 3)

# %%
catsmall=imresize(cat,[100,100,3])
print_typeshape(catsmall)
plt.figure(1)
plt.imshow(catsmall)
plt.draw()
# Out:
# Type is <class 'numpy.ndarray'>
# Shape is (100, 100, 3)
# C:\Users\la\Anaconda3\lib\site-packages\scipy\misc\pilutil.py:480: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# C:\Users\la\Anaconda3\lib\site-packages\scipy\misc\pilutil.py:483: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
catsmall.shape
# Out:
# (100, 100, 3)

# %%
def rgb2gray(rgb):
    if len(rgb.shape) is 3:
        return np.dot(rgb[...,:3],[.299,.587,.114])
    else:
        print('current image is gray already')
        return rgb

# %%
catsmallgray.shape
# Out:
# (100, 100)

# %%
catsmall.shape
# Out:
# (100, 100, 3)

# %%
plt.imshow(catsmall/255)

# %%
catsmallgray=rgb2gray(catsmall)
print(catsmallgray.shape)
print(type(catsmallgray))
# Out:
# (100, 100)
# <class 'numpy.ndarray'>

# %%
plt.imshow(catsmallgray, cmap=plt.get_cmap('gray'))
plt.colorbar()
plt.show()

# %%
catrowvew=np.reshape(catsmallgray,(-1,1))
catrowvew.shape
# Out:
# (10000, 1)

# %%
catsmallgray.reshape(-1,1).shape
# Out:
# (10000, 1)

# %%
cwd=os.getcwd()
cwd
# Out:
# 'C:\\Users\\la'

# %%
cwdb=os.getcwdb()
cwdb
# Out:
# C:\Users\la\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: The Windows bytes API has been deprecated, use Unicode filenames instead
#   if __name__ == '__main__':
# b'C:\\Users\\la'

# %%
path=cwd+'\\data\\'
path
# Out:
# 'C:\\Users\\la\\data\\'

# %%
flist=os.listdir(path)
len(flist)
# Out:
# 1

# %%
flist
# Out:
# ['cat.jpg']

# %%
ext=os.path.splitext(flist[0])
ext
# Out:
# ('cat', '.jpg')
