# %%
import pandas as pd
data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
df_data=pd.read_csv(data_url, sep='\s+', header=None)
df_data.columns=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
#14개 항목의 feature 이름을 지을 수 있다.
df_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
import numpy as np
weight_vector = np.array([[1],[1],[1]])
x_vector=np.array([[3],[4],[5]])
weight_vector.T.dot(x_vector)
# Out:
# array([[12]])

# %%
a=[1,2,3]
a
b=[[1],[2],[3]]
b
# Out:
# [[1], [2], [3]]

# %%
c=np.array([1,2,3])
d=np.array([[1],[2],[3]])
c.dot(d)
# Out:
# array([14])

# %%
df_data.as_matrix()
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 3.9690e+02, 4.9800e+00,
#         2.4000e+01],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 3.9690e+02, 9.1400e+00,
#         2.1600e+01],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 3.9283e+02, 4.0300e+00,
#         3.4700e+01],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 5.6400e+00,
#         2.3900e+01],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 3.9345e+02, 6.4800e+00,
#         2.2000e+01],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 7.8800e+00,
#         1.1900e+01]])

# %%
df_data.shape
# Out:
# (506, 14)

# %%
import numpy as np
weight_vector = np.array([[1],[1],[1]])
x_vector=np.array([[3],[4],[5]])
weight_vector.T.dot(x_vector)
# Out:
# array([[12]])

# %%
df_data.values[0]
# Out:
# array([6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#        6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#        4.980e+00, 1.000e+00])

# %%
df_data['weight_0']=1
df_data
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311.0
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311.0
# ...

# %%
df_data=df_data.drop("MEDV", axis=1)

# %%
df_data.shape
# Out:
# (506, 14)

# %%
df_matrix=df_data.as_matrix()

# %%
weight_vector = np.random.rand

# %%
x=np.random.rand(10)
x
# Out:
# array([0.38936462, 0.91976421, 0.3222368 , 0.38251954, 0.58981674,
#        0.69025693, 0.49741601, 0.64319154, 0.45798342, 0.69061967])

# %%
np.random.randint(10)
# Out:
# 3

# %%
y=np.random.shuffle(x)
x
# Out:
# array([0.64319154, 0.45798342, 0.69061967, 0.69025693, 0.3222368 ,
#        0.58981674, 0.49741601, 0.38936462, 0.38251954, 0.91976421])

# %%
np.random.choice(x, 6, replace=True, p=None)
# Out:
# array([0.49741601, 0.69025693, 0.45798342, 0.3222368 , 0.91976421,
#        0.45798342])

# %%
x=np.random.randint(5,10,10)
x
# Out:
# array([9, 8, 8, 8, 8, 6, 5, 9, 8, 9])

# %%
c=np.random.seed(100)
c

# %%
np.unique(x)
# Out:
# array([5, 6, 8, 9])

# %%
a = np.array(['a', 'b', 'b', 'c', 'a'])
index, count = np.unique(a, return_counts=True)
index
# Out:
# array(['a', 'b', 'c'], dtype='<U1')

# %%
np.bincount([1, 1, 2, 2, 2, 3], minlength=6)
# Out:
# array([0, 2, 3, 1, 0, 0], dtype=int64)

# %%
x=np.random.randint(1,7,10)
x
# Out:
# array([5, 5, 4, 4, 4, 2, 2, 6, 4, 1])

# %%
np.bincount(x, minlength=7)
# Out:
# array([0, 1, 2, 0, 4, 2, 1], dtype=int64)
