# %%
import pandas as pd
import urllib

url="http://aima.cs.berkeley.edu/data/iris.csv"
set1=urllib.request.Request(url)
iris_p=urllib.request.urlopen(set1)
iris_other=pd.read_csv(iris_p, sep=',',decimal='.', header=None,
                      names=['sepal_length','sepal_width', 'petal_length','petal_width','target'])
iris_other.head()                       
iris_filename='C:\\Users\\la\\Desktop\\PythonDataScienceEssentialsSecondEdition_Code\\Chapter 2\\code\\datasets-uci-iris.csv'
iris=iris_other
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target'], dtype='object')

# %%
Y=iris['target']
X=iris[['sepal_length','sepal_width']]
X.shape,Y.shape
# Out:
# ((150, 2), (150,))

# %%
filename='C:\\Users\\la\\Desktop\\PythonDataScienceEssentialsSecondEdition_Code\\Chapter 2\\code\\a_loading_example_1.csv'
fake_dataset=pd.read_csv(filename,  sep=',')
fake_dataset
# Out:
#        Date  Temperature_city_1  Temperature_city_2  Temperature_city_3  \
# 0  20140910                80.0                32.0                  40
# 1  20140911               100.0                50.0                  36
# 2  20140912               102.0                55.0                  46
# 3  20140913                60.0                20.0                  35
# 4  20140914                60.0                 NaN                  32
# 5  20140915                 NaN                57.0                  42
#
#    Which_destination
# 0                  1
# 1                  2
# 2                  1
# 3                  3
# 4                  3
# 5                  2

# %%
fake_dataset=pd.read_csv(filename, parse_dates=[0] )
fake_dataset
# Out:
#         Date  Temperature_city_1  Temperature_city_2  Temperature_city_3  \
# 0 2014-09-10                80.0                32.0                  40
# 1 2014-09-11               100.0                50.0                  36
# 2 2014-09-12               102.0                55.0                  46
# 3 2014-09-13                60.0                20.0                  35
# 4 2014-09-14                60.0                 NaN                  32
# 5 2014-09-15                 NaN                57.0                  42
#
#    Which_destination
# 0                  1
# 1                  2
# 2                  1
# 3                  3
# 4                  3
# 5                  2

# %%
fake_dataset.fillna(fake_dataset.mean(axis=0))
# Out:
#         Date  Temperature_city_1  Temperature_city_2  Temperature_city_3  \
# 0 2014-09-10                80.0                32.0                  40
# 1 2014-09-11               100.0                50.0                  36
# 2 2014-09-12               102.0                55.0                  46
# 3 2014-09-13                60.0                20.0                  35
# 4 2014-09-14                60.0                42.8                  32
# 5 2014-09-15                80.4                57.0                  42
#
#    Which_destination
# 0                  1
# 1                  2
# 2                  1
# 3                  3
# 4                  3
# 5                  2

# %%
bad_dataset=pd.read_csv("C:\\Users\\la\\Desktop\\PythonDataScienceEssentialsSecondEdition_Code\\Chapter 2\\code\\a_loading_example_2.csv", error_bad_lines=False)
bad_dataset
# Out:
# b'Skipping line 4: expected 3 fields, saw 4\n'
#    Val1  Val2  Val3
# 0     0     0     0
# 1     1     1     1
# 2     3     3     3

# %%
iris_chunks=pd.read_csv(iris_filename,header=None,names=['c1','c2','c3','c4','c5'], chunksize=10)
for chunk in iris_chunks:
    print('Shape : ',chunk.shape)
    print(chunk,'\n')
# Out:
# Shape :  (10, 5)
#     c1   c2   c3   c4           c5
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa
# 5  5.4  3.9  1.7  0.4  Iris-setosa
# 6  4.6  3.4  1.4  0.3  Iris-setosa
# 7  5.0  3.4  1.5  0.2  Iris-setosa
# 8  4.4  2.9  1.4  0.2  Iris-setosa
# 9  4.9  3.1  1.5  0.1  Iris-setosa
#
# Shape :  (10, 5)
#      c1   c2   c3   c4           c5
# 10  5.4  3.7  1.5  0.2  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 12  4.8  3.0  1.4  0.1  Iris-setosa
# 13  4.3  3.0  1.1  0.1  Iris-setosa
# 14  5.8  4.0  1.2  0.2  Iris-setosa
# 15  5.7  4.4  1.5  0.4  Iris-setosa
# 16  5.4  3.9  1.3  0.4  Iris-setosa
# 17  5.1  3.5  1.4  0.3  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 19  5.1  3.8  1.5  0.3  Iris-setosa
#
# Shape :  (10, 5)
#      c1   c2   c3   c4           c5
# 20  5.4  3.4  1.7  0.2  Iris-setosa
# 21  5.1  3.7  1.5  0.4  Iris-setosa
# ...
