# %%
import numpy as np
import mglearn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from matplotlib.pyplot import rc
rc('font',family='New Gulim')

# %%
from sklearn.datasets import load_iris
iris= load_iris()# 간단한 그리드 서치 구현
from sklearn.svm import SVC
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target,
                                                    random_state=0)
print("훈련 세트의 크기: {}   테스트 세트의 크기: {}".format(
      X_train.shape[0], X_test.shape[0]))

best_score = 0

for gamma in [0.001, 0.01, 0.1, 1, 10, 100]:
    for C in [0.001, 0.01, 0.1, 1, 10, 100]:
        # 매개변수의 각 조합에 대해 SVC를 훈련시킵니다
        svm = SVC(gamma=gamma, C=C)
        svm.fit(X_train, y_train)
        # 테스트 세트로 SVC를 평가합니다
        score = svm.score(X_test, y_test)
        # 점수가 더 높으면 매개변수와 함께 기록합니다
        if score > best_score:
            best_score = score
            best_parameters = {'C': C, 'gamma': gamma}
            
print("최고 점수: {:.2f}".format(best_score))
print("최적 파라미터: {}".format(best_parameters))
# Out:
# 훈련 세트의 크기: 112   테스트 세트의 크기: 38
# 최고 점수: 0.97
# 최적 파라미터: {'C': 100, 'gamma': 0.001}

# %%
mglearn.plots.plot_threefold_split()

# %%
from sklearn.svm import SVC
# 데이터를 훈련+검증 세트 그리고 테스트 세트로 분할
X_trainval, X_test, y_trainval, y_test = train_test_split(
    iris.data, iris.target, random_state=0)
# 훈련+검증 세트를 훈련 세트와 검증 세트로 분할
X_train, X_valid, y_train, y_valid = train_test_split(
    X_trainval, y_trainval, random_state=1)
print("훈련 세트의 크기: {}   검증 세트의 크기: {}   테스트 세트의 크기:"
      " {}\n".format(X_train.shape[0], X_valid.shape[0], X_test.shape[0]))

best_score = 0

for gamma in [0.001, 0.01, 0.1, 1, 10, 100]:
    for C in [0.001, 0.01, 0.1, 1, 10, 100]:
        # 매개변수의 각 조합에 대해 SVC를 훈련시킵니다
        svm = SVC(gamma=gamma, C=C)
        svm.fit(X_train, y_train)
        # 검증 세트로 SVC를 평가합니다
        score = svm.score(X_valid, y_valid)
        # 점수가 더 높으면 매개변수와 함께 기록합니다
        if score > best_score:
            best_score = score
            best_parameters = {'C': C, 'gamma': gamma}

# 훈련 세트와 검증 세트를 합쳐 모델을 다시 만든 후
# 테스트 세트를 사용해 평가합니다
svm = SVC(**best_parameters)
svm.fit(X_trainval, y_trainval)
test_score = svm.score(X_test, y_test)
print("검증 세트에서 최고 점수: {:.2f}".format(best_score))
print("최적 파라미터: ", best_parameters)
print("최적 파라미터에서 테스트 세트 점수: {:.2f}".format(test_score))
# Out:
# 훈련 세트의 크기: 84   검증 세트의 크기: 28   테스트 세트의 크기: 38
#
# 검증 세트에서 최고 점수: 0.96
# 최적 파라미터:  {'C': 10, 'gamma': 0.001}
# 최적 파라미터에서 테스트 세트 점수: 0.92

# %%
from sklearn.model_selection import cross_val_score
for gamma in [0.001, 0.01, 0.1, 1, 10, 100]:
    for C in [0.001, 0.01, 0.1, 1, 10, 100]:
        # 매개변수의 각 조합에 대해 SVC를 훈련시킵니다
        svm = SVC(gamma=gamma, C=C)
        # 교차 검증을 적용합니다
        scores = cross_val_score(svm, X_trainval, y_trainval, cv=5)
        # 교차 검증 정확도의 평균을 계산합니다
        score = np.mean(scores)
        # 점수가 더 높으면 매개변수와 함께 기록합니다
        if score > best_score:
            best_score = score
            best_parameters = {'C': C, 'gamma': gamma}
# 훈련 세트와 검증 세트를 합쳐 모델을 다시 만듭니다
svm = SVC(**best_parameters)
svm.fit(X_trainval, y_trainval)
# Out:
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
mglearn.plots.plot_cross_val_selection()

# %%
mglearn.plots.plot_grid_search_overview()

# %%
param_grid={'C':[0.001,0.01,0.1,1,10,100],
           'gamma':[0.001,0.01,0.1,1,10,100]}
print("매개변수 그리드:\n{}".format(param_grid))
# Out:
# 매개변수 그리드:
# {'C': [0.001, 0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
grid_search=GridSearchCV(SVC(), param_grid, cv=5, return_train_score=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target,
                                                    random_state=0)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['rbf'], 'C': [0.001, 0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}, {'kernel': ['linear'], 'C': [0.001, 0.01, 0.1, 1, 10, 100]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
print("테스트 세트 점수: {:.2f}".format(grid_search.score(X_test, y_test)))
# Out:
# 테스트 세트 점수: 0.97

# %%
print("최적 매개변수: {}".format(grid_search.best_params_))
print("최고 교차 검증 점수: {:.2f}".format(grid_search.best_score_))
# Out:
# 최적 매개변수: {'C': 100, 'gamma': 0.01}
# 최고 교차 검증 점수: 0.97

# %%
print("최고 성능 모델:\n{}".format(grid_search.best_estimator_))
# Out:
# 최고 성능 모델:
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
results=pd.DataFrame(grid_search.cv_results_)
display((results.head()))
# Out:
#    mean_fit_time  mean_score_time  mean_test_score  mean_train_score param_C  \
# 0       0.000399         0.000399         0.366071          0.366079   0.001
# 1       0.000401         0.000198         0.366071          0.366079   0.001
# 2       0.000599         0.000000         0.366071          0.366079   0.001
# 3       0.000199         0.000400         0.366071          0.366079   0.001
# 4       0.000393         0.000000         0.366071          0.366079   0.001
#
#   param_gamma param_kernel                                         params  \
# 0       0.001          rbf  {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 1        0.01          rbf   {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# 2         0.1          rbf    {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# 3           1          rbf      {'C': 0.001, 'gamma': 1, 'kernel': 'rbf'}
# 4          10          rbf     {'C': 0.001, 'gamma': 10, 'kernel': 'rbf'}
#
#    rank_test_score  split0_test_score  split0_train_score  split1_test_score  \
# 0               27              0.375            0.363636           0.347826
# 1               27              0.375            0.363636           0.347826
# 2               27              0.375            0.363636           0.347826
# 3               27              0.375            0.363636           0.347826
# 4               27              0.375            0.363636           0.347826
#
#    split1_train_score  split2_test_score  split2_train_score  \
# 0            0.370787           0.363636            0.366667
# 1            0.370787           0.363636            0.366667
# 2            0.370787           0.363636            0.366667
# 3            0.370787           0.363636            0.366667
# 4            0.370787           0.363636            0.366667
#
#    split3_test_score  split3_train_score  split4_test_score  \
# 0           0.363636            0.366667           0.380952
# 1           0.363636            0.366667           0.380952
# 2           0.363636            0.366667           0.380952
# 3           0.363636            0.366667           0.380952
# 4           0.363636            0.366667           0.380952
#
#    split4_train_score  std_fit_time  std_score_time  std_test_score  \
# 0            0.362637      0.000489        0.000489        0.011371
# 1            0.362637      0.000491        0.000397        0.011371
# 2            0.362637      0.000489        0.000000        0.011371
# 3            0.362637      0.000399        0.000489        0.011371
# 4            0.362637      0.000481        0.000000        0.011371
#
#    std_train_score
# 0         0.002852
# 1         0.002852
# 2         0.002852
# 3         0.002852
# 4         0.002852

# %%
scores=np.array(results.mean_test_score).reshape(6,6)
mglearn.tools.heatmap(scores, xlabel='gamma', xticklabels=param_grid['gamma'],
                      ylabel='C', yticklabels=param_grid['C'], cmap="viridis")

# %%
fig, axes = plt.subplots(1, 3, figsize=(13, 5))

param_grid_linear = {'C': np.linspace(1, 2, 6),
                     'gamma':  np.linspace(1, 2, 6)}

param_grid_one_log = {'C': np.linspace(1, 2, 6),
                     'gamma':  np.logspace(-3, 2, 6)}

param_grid_range = {'C': np.logspace(-3, 2, 6),
                     'gamma':  np.logspace(-7, -2, 6)}

for param_grid, ax in zip([param_grid_linear, param_grid_one_log,
                           param_grid_range], axes):
    grid_search = GridSearchCV(SVC(), param_grid, cv=5)
    grid_search.fit(X_train, y_train)
    scores = grid_search.cv_results_['mean_test_score'].reshape(6, 6)

    # 교차 검증 평균 점수의 히트맵 그래프
    scores_image = mglearn.tools.heatmap(
        scores, xlabel='gamma', ylabel='C', xticklabels=param_grid['gamma'],
        yticklabels=param_grid['C'], cmap="viridis", ax=ax)
    
plt.colorbar(scores_image, ax=axes.tolist())

# %%
param_grid = [{'kernel': ['rbf'],
               'C': [0.001, 0.01, 0.1, 1, 10, 100],
               'gamma': [0.001, 0.01, 0.1, 1, 10, 100]},
              {'kernel': ['linear'],
               'C': [0.001, 0.01, 0.1, 1, 10, 100]}]
print("그리드 목록:\n{}".format(param_grid))
# Out:
# 그리드 목록:
# [{'kernel': ['rbf'], 'C': [0.001, 0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}, {'kernel': ['linear'], 'C': [0.001, 0.01, 0.1, 1, 10, 100]}]

# %%
grid_search = GridSearchCV(SVC(), param_grid, cv=5, return_train_score=True)
grid_search.fit(X_train, y_train)
print("최적 파라미터: {}".format(grid_search.best_params_))
print("최고 교차 검증 점수: {:.2f}".format(grid_search.best_score_))
# Out:
# 최적 파라미터: {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 최고 교차 검증 점수: 0.97

# %%
results = pd.DataFrame(grid_search.cv_results_)
# 좀 더 나은 출력을 위해 결과를 전치시킵니다
display(results.T)
# Out:
#                                                                0   \
# mean_fit_time                                         0.000405502
# mean_score_time                                       0.000404501
# mean_test_score                                          0.366071
# mean_train_score                                         0.366079
# param_C                                                     0.001
# param_gamma                                                 0.001
# param_kernel                                                  rbf
# params              {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# rank_test_score                                                27
# split0_test_score                                           0.375
# split0_train_score                                       0.363636
# split1_test_score                                        0.347826
# split1_train_score                                       0.370787
# split2_test_score                                        0.363636
# split2_train_score                                       0.366667
# split3_test_score                                        0.363636
# split3_train_score                                       0.366667
# split4_test_score                                        0.380952
# split4_train_score                                       0.362637
# std_fit_time                                          0.000496681
# std_score_time                                        0.000495484
# std_test_score                                          0.0113708
# std_train_score                                        0.00285176
#
#                                                               1   \
# mean_fit_time                                        0.000399017
# mean_score_time                                      0.000394535
# mean_test_score                                         0.366071
# mean_train_score                                        0.366079
# param_C                                                    0.001
# param_gamma                                                 0.01
# param_kernel                                                 rbf
# params              {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# rank_test_score                                               27
# split0_test_score                                          0.375
# split0_train_score                                      0.363636
# split1_test_score                                       0.347826
# split1_train_score                                      0.370787
# split2_test_score                                       0.363636
# split2_train_score                                      0.366667
# split3_test_score                                       0.363636
# split3_train_score                                      0.366667
# split4_test_score                                       0.380952
# split4_train_score                                      0.362637
# std_fit_time                                         0.000488694
# std_score_time                                       0.000483255
# std_test_score                                         0.0113708
# std_train_score                                       0.00285176
#
#                                                              2   \
# mean_fit_time                                       0.000398922
# mean_score_time                                     0.000199461
# mean_test_score                                        0.366071
# mean_train_score                                       0.366079
# param_C                                                   0.001
# param_gamma                                                 0.1
# param_kernel                                                rbf
# params              {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# rank_test_score                                              27
# split0_test_score                                         0.375
# split0_train_score                                     0.363636
# split1_test_score                                      0.347826
# split1_train_score                                     0.370787
# split2_test_score                                      0.363636
# split2_train_score                                     0.366667
# split3_test_score                                      0.363636
# split3_train_score                                     0.366667
# split4_test_score                                      0.380952
# split4_train_score                                     0.362637
# std_fit_time                                        0.000488578
# std_score_time                                      0.000398922
# std_test_score                                        0.0113708
# std_train_score                                      0.00285176
#
#                                                            3   \
# mean_fit_time                                     0.000408602
# mean_score_time                                   0.000199461
# mean_test_score                                      0.366071
# mean_train_score                                     0.366079
# param_C                                                 0.001
# param_gamma                                                 1
# param_kernel                                              rbf
# params              {'C': 0.001, 'gamma': 1, 'kernel': 'rbf'}
# rank_test_score                                            27
# split0_test_score                                       0.375
# split0_train_score                                   0.363636
# split1_test_score                                    0.347826
# split1_train_score                                   0.370787
# split2_test_score                                    0.363636
# split2_train_score                                   0.366667
# split3_test_score                                    0.363636
# split3_train_score                                   0.366667
# split4_test_score                                    0.380952
# split4_train_score                                   0.362637
# std_fit_time                                       0.00050044
# std_score_time                                    0.000398922
# std_test_score                                      0.0113708
# std_train_score                                    0.00285176
#
#                                                             4   \
# mean_fit_time                                      0.000797415
# mean_score_time                                              0
# mean_test_score                                       0.366071
# mean_train_score                                      0.366079
# param_C                                                  0.001
# param_gamma                                                 10
# param_kernel                                               rbf
# params              {'C': 0.001, 'gamma': 10, 'kernel': 'rbf'}
# rank_test_score                                             27
# split0_test_score                                        0.375
# split0_train_score                                    0.363636
# split1_test_score                                     0.347826
# split1_train_score                                    0.370787
# split2_test_score                                     0.363636
# split2_train_score                                    0.366667
# split3_test_score                                     0.363636
# split3_train_score                                    0.366667
# split4_test_score                                     0.380952
# split4_train_score                                    0.362637
# std_fit_time                                        0.00039871
# std_score_time                                               0
# std_test_score                                       0.0113708
# std_train_score                                     0.00285176
#
#                                                              5   \
# mean_fit_time                                       0.000593042
# mean_score_time                                               0
# mean_test_score                                        0.366071
# mean_train_score                                       0.366079
# param_C                                                   0.001
# param_gamma                                                 100
# param_kernel                                                rbf
# params              {'C': 0.001, 'gamma': 100, 'kernel': 'rbf'}
# rank_test_score                                              27
# split0_test_score                                         0.375
# split0_train_score                                     0.363636
# split1_test_score                                      0.347826
# split1_train_score                                     0.370787
# split2_test_score                                      0.363636
# split2_train_score                                     0.366667
# split3_test_score                                      0.363636
# split3_train_score                                     0.366667
# split4_test_score                                      0.380952
# split4_train_score                                     0.362637
# std_fit_time                                        0.000484323
# std_score_time                                                0
# std_test_score                                        0.0113708
# std_train_score                                      0.00285176
#
#                                                               6   \
# mean_fit_time                                        0.000398922
# mean_score_time                                      0.000199413
# mean_test_score                                         0.366071
# mean_train_score                                        0.366079
# param_C                                                     0.01
# param_gamma                                                0.001
# param_kernel                                                 rbf
# params              {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# rank_test_score                                               27
# split0_test_score                                          0.375
# split0_train_score                                      0.363636
# split1_test_score                                       0.347826
# split1_train_score                                      0.370787
# split2_test_score                                       0.363636
# split2_train_score                                      0.366667
# split3_test_score                                       0.363636
# split3_train_score                                      0.366667
# split4_test_score                                       0.380952
# split4_train_score                                      0.362637
# std_fit_time                                         0.000488578
# std_score_time                                       0.000398827
# std_test_score                                         0.0113708
# std_train_score                                       0.00285176
#
#                                                              7   \
# mean_fit_time                                       0.000398827
# mean_score_time                                     0.000199509
# mean_test_score                                        0.366071
# mean_train_score                                       0.366079
# param_C                                                    0.01
# param_gamma                                                0.01
# param_kernel                                                rbf
# params              {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# rank_test_score                                              27
# split0_test_score                                         0.375
# split0_train_score                                     0.363636
# split1_test_score                                      0.347826
# split1_train_score                                     0.370787
# split2_test_score                                      0.363636
# split2_train_score                                     0.366667
# split3_test_score                                      0.363636
# split3_train_score                                     0.366667
# split4_test_score                                      0.380952
# split4_train_score                                     0.362637
# std_fit_time                                        0.000488461
# std_score_time                                      0.000399017
# std_test_score                                        0.0113708
# std_train_score                                      0.00285176
#
#                                                             8   \
# mean_fit_time                                      0.000598383
# mean_score_time                                              0
# mean_test_score                                       0.366071
# mean_train_score                                      0.366079
# param_C                                                   0.01
# param_gamma                                                0.1
# param_kernel                                               rbf
# params              {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# rank_test_score                                             27
# split0_test_score                                        0.375
# split0_train_score                                    0.363636
# split1_test_score                                     0.347826
# split1_train_score                                    0.370787
# split2_test_score                                     0.363636
# split2_train_score                                    0.366667
# split3_test_score                                     0.363636
# split3_train_score                                    0.366667
# split4_test_score                                     0.380952
# split4_train_score                                    0.362637
# std_fit_time                                       0.000488579
# std_score_time                                               0
# std_test_score                                       0.0113708
# std_train_score                                     0.00285176
#
#                                                           9   \
# mean_fit_time                                    0.000404453
# mean_score_time                                  0.000199461
# mean_test_score                                     0.366071
# mean_train_score                                    0.366079
# param_C                                                 0.01
# param_gamma                                                1
# param_kernel                                             rbf
# params              {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
# rank_test_score                                           27
# split0_test_score                                      0.375
# split0_train_score                                  0.363636
# split1_test_score                                   0.347826
# split1_train_score                                  0.370787
# split2_test_score                                   0.363636
# split2_train_score                                  0.366667
# split3_test_score                                   0.363636
# split3_train_score                                  0.366667
# split4_test_score                                   0.380952
# split4_train_score                                  0.362637
# std_fit_time                                     0.000495427
# std_score_time                                   0.000398922
# std_test_score                                     0.0113708
# std_train_score                                   0.00285176
#
#                                                            10  \
# mean_fit_time                                     0.000600481
# mean_score_time                                             0
# mean_test_score                                      0.366071
# mean_train_score                                     0.366079
# param_C                                                  0.01
# param_gamma                                                10
# param_kernel                                              rbf
# params              {'C': 0.01, 'gamma': 10, 'kernel': 'rbf'}
# rank_test_score                                            27
# split0_test_score                                       0.375
# split0_train_score                                   0.363636
# split1_test_score                                    0.347826
# split1_train_score                                   0.370787
# split2_test_score                                    0.363636
# split2_train_score                                   0.366667
# split3_test_score                                    0.363636
# split3_train_score                                   0.366667
# split4_test_score                                    0.380952
# split4_train_score                                   0.362637
# std_fit_time                                      0.000490353
# std_score_time                                              0
# std_test_score                                      0.0113708
# std_train_score                                    0.00285176
#
#                                                             11  \
# mean_fit_time                                      0.000599289
# mean_score_time                                     0.00039773
# mean_test_score                                       0.366071
# mean_train_score                                      0.366079
# param_C                                                   0.01
# param_gamma                                                100
# param_kernel                                               rbf
# params              {'C': 0.01, 'gamma': 100, 'kernel': 'rbf'}
# rank_test_score                                             27
# split0_test_score                                        0.375
# split0_train_score                                    0.363636
# split1_test_score                                     0.347826
# split1_train_score                                    0.370787
# split2_test_score                                     0.363636
# split2_train_score                                    0.366667
# split3_test_score                                     0.363636
# split3_train_score                                    0.366667
# split4_test_score                                     0.380952
# split4_train_score                                    0.362637
# std_fit_time                                       0.000489321
# std_score_time                                     0.000487119
# std_test_score                                       0.0113708
# std_train_score                                     0.00285176
#
#                                                              12  \
# mean_fit_time                                       0.000603771
# mean_score_time                                     0.000199699
# mean_test_score                                        0.366071
# mean_train_score                                       0.366079
# param_C                                                     0.1
# param_gamma                                               0.001
# param_kernel                                                rbf
# params              {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# rank_test_score                                              27
# split0_test_score                                         0.375
# split0_train_score                                     0.363636
# split1_test_score                                      0.347826
# split1_train_score                                     0.370787
# split2_test_score                                      0.363636
# split2_train_score                                     0.366667
# split3_test_score                                      0.363636
# split3_train_score                                     0.366667
# split4_test_score                                      0.380952
# split4_train_score                                     0.362637
# std_fit_time                                         0.00049307
# std_score_time                                      0.000399399
# std_test_score                                        0.0113708
# std_train_score                                      0.00285176
#
#                                                             13  \
# mean_fit_time                                      0.000398636
# mean_score_time                                              0
# mean_test_score                                       0.696429
# mean_train_score                                      0.696424
# param_C                                                    0.1
# param_gamma                                               0.01
# param_kernel                                               rbf
# params              {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# rank_test_score                                             22
# split0_test_score                                     0.708333
# split0_train_score                                    0.693182
# split1_test_score                                     0.695652
# split1_train_score                                    0.696629
# split2_test_score                                     0.681818
# split2_train_score                                         0.7
# split3_test_score                                     0.681818
# split3_train_score                                         0.7
# split4_test_score                                     0.714286
# split4_train_score                                    0.692308
# std_fit_time                                       0.000488227
# std_score_time                                               0
# std_test_score                                       0.0131963
# std_train_score                                     0.00325802
#
#                                                            14  \
# mean_fit_time                                     0.000204992
# mean_score_time                                   0.000194025
# mean_test_score                                      0.919643
# mean_train_score                                     0.919744
# param_C                                                   0.1
# param_gamma                                               0.1
# param_kernel                                              rbf
# params              {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# rank_test_score                                            17
# split0_test_score                                    0.916667
# split0_train_score                                   0.943182
# split1_test_score                                    0.913043
# split1_train_score                                   0.932584
# split2_test_score                                           1
# split2_train_score                                        0.9
# split3_test_score                                    0.863636
# split3_train_score                                   0.888889
# split4_test_score                                    0.904762
# split4_train_score                                   0.934066
# std_fit_time                                      0.000409985
# std_score_time                                     0.00038805
# std_test_score                                      0.0440102
# std_train_score                                     0.0212659
#
#                                                          15  \
# mean_fit_time                                   0.000594187
# mean_score_time                                           0
# mean_test_score                                    0.955357
# mean_train_score                                   0.959846
# param_C                                                 0.1
# param_gamma                                               1
# param_kernel                                            rbf
# params              {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# rank_test_score                                           9
# split0_test_score                                         1
# split0_train_score                                 0.954545
# split1_test_score                                  0.913043
# split1_train_score                                 0.977528
# split2_test_score                                         1
# split2_train_score                                 0.944444
# split3_test_score                                  0.909091
# split3_train_score                                 0.966667
# split4_test_score                                  0.952381
# split4_train_score                                 0.956044
# std_fit_time                                    0.000485284
# std_score_time                                            0
# std_test_score                                    0.0401043
# std_train_score                                   0.0113043
#
#                                                           16  \
# mean_fit_time                                     0.00059824
# mean_score_time                                  0.000194073
# mean_test_score                                     0.366071
# mean_train_score                                     0.38171
# param_C                                                  0.1
# param_gamma                                               10
# param_kernel                                             rbf
# params              {'C': 0.1, 'gamma': 10, 'kernel': 'rbf'}
# rank_test_score                                           27
# split0_test_score                                      0.375
# split0_train_score                                     0.375
# split1_test_score                                   0.347826
# split1_train_score                                  0.382022
# split2_test_score                                   0.363636
# split2_train_score                                  0.366667
# split3_test_score                                   0.363636
# split3_train_score                                  0.422222
# split4_test_score                                   0.380952
# split4_train_score                                  0.362637
# std_fit_time                                     0.000488461
# std_score_time                                   0.000388145
# std_test_score                                     0.0113708
# std_train_score                                    0.0213374
#
#                                                            17  \
# mean_fit_time                                     0.000598383
# mean_score_time                                   0.000199461
# mean_test_score                                      0.366071
# mean_train_score                                     0.366079
# param_C                                                   0.1
# param_gamma                                               100
# param_kernel                                              rbf
# params              {'C': 0.1, 'gamma': 100, 'kernel': 'rbf'}
# rank_test_score                                            27
# split0_test_score                                       0.375
# split0_train_score                                   0.363636
# split1_test_score                                    0.347826
# split1_train_score                                   0.370787
# split2_test_score                                    0.363636
# split2_train_score                                   0.366667
# split3_test_score                                    0.363636
# split3_train_score                                   0.366667
# split4_test_score                                    0.380952
# split4_train_score                                   0.362637
# std_fit_time                                      0.000488578
# std_score_time                                    0.000398922
# std_test_score                                      0.0113708
# std_train_score                                    0.00285176
#
#                                                            18  \
# mean_fit_time                                     0.000598335
# mean_score_time                                   0.000398922
# mean_test_score                                      0.696429
# mean_train_score                                     0.696424
# param_C                                                     1
# param_gamma                                             0.001
# param_kernel                                              rbf
# params              {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# rank_test_score                                            22
# split0_test_score                                    0.708333
# split0_train_score                                   0.693182
# split1_test_score                                    0.695652
# split1_train_score                                   0.696629
# split2_test_score                                    0.681818
# split2_train_score                                        0.7
# split3_test_score                                    0.681818
# split3_train_score                                        0.7
# split4_test_score                                    0.714286
# split4_train_score                                   0.692308
# std_fit_time                                      0.000488539
# std_score_time                                    0.000488578
# std_test_score                                      0.0131963
# std_train_score                                    0.00325802
#
#                                                           19  \
# mean_fit_time                                    0.000199461
# mean_score_time                                  0.000199461
# mean_test_score                                     0.928571
# mean_train_score                                    0.935325
# param_C                                                    1
# param_gamma                                             0.01
# param_kernel                                             rbf
# params              {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# rank_test_score                                           15
# split0_test_score                                      0.875
# split0_train_score                                  0.943182
# split1_test_score                                   0.913043
# split1_train_score                                   0.94382
# split2_test_score                                          1
# split2_train_score                                  0.922222
# split3_test_score                                   0.909091
# split3_train_score                                  0.933333
# split4_test_score                                   0.952381
# split4_train_score                                  0.934066
# std_fit_time                                     0.000398922
# std_score_time                                   0.000398922
# std_test_score                                     0.0429827
# std_train_score                                   0.00788839
#
#                                                          20  \
# mean_fit_time                                   0.000598383
# mean_score_time                                           0
# mean_test_score                                    0.964286
# mean_train_score                                    0.97765
# param_C                                                   1
# param_gamma                                             0.1
# param_kernel                                            rbf
# params              {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# rank_test_score                                           3
# split0_test_score                                         1
# split0_train_score                                 0.965909
# split1_test_score                                  0.956522
# split1_train_score                                 0.988764
# split2_test_score                                         1
# split2_train_score                                 0.966667
# split3_test_score                                  0.909091
# split3_train_score                                 0.988889
# split4_test_score                                  0.952381
# split4_train_score                                 0.978022
# std_fit_time                                    0.000488578
# std_score_time                                            0
# std_test_score                                    0.0340769
# std_train_score                                   0.0100842
#
#                                                        21  \
# mean_fit_time                                           0
# mean_score_time                               0.000398874
# mean_test_score                                  0.946429
# mean_train_score                                 0.984393
# param_C                                                 1
# param_gamma                                             1
# param_kernel                                          rbf
# params              {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# rank_test_score                                        11
# split0_test_score                                0.916667
# split0_train_score                               0.988636
# split1_test_score                                0.956522
# split1_train_score                               0.977528
# split2_test_score                                       1
# split2_train_score                               0.977778
# split3_test_score                                0.909091
# split3_train_score                                      1
# split4_test_score                                0.952381
# split4_train_score                               0.978022
# std_fit_time                                            0
# std_score_time                                0.000488519
# std_test_score                                  0.0324799
# std_train_score                                0.00886637
#
#                                                         22  \
# mean_fit_time                                  0.000598335
# mean_score_time                                          0
# mean_test_score                                   0.919643
# mean_train_score                                         1
# param_C                                                  1
# param_gamma                                             10
# param_kernel                                           rbf
# params              {'C': 1, 'gamma': 10, 'kernel': 'rbf'}
# rank_test_score                                         17
# split0_test_score                                    0.875
# split0_train_score                                       1
# split1_test_score                                 0.956522
# split1_train_score                                       1
# split2_test_score                                        1
# split2_train_score                                       1
# split3_test_score                                 0.818182
# split3_train_score                                       1
# split4_test_score                                 0.952381
# split4_train_score                                       1
# std_fit_time                                   0.000488539
# std_score_time                                           0
# std_test_score                                   0.0647906
# std_train_score                                          0
#
#                                                          23  \
# mean_fit_time                                   0.000598621
# mean_score_time                                 0.000199461
# mean_test_score                                    0.508929
# mean_train_score                                          1
# param_C                                                   1
# param_gamma                                             100
# param_kernel                                            rbf
# params              {'C': 1, 'gamma': 100, 'kernel': 'rbf'}
# rank_test_score                                          26
# split0_test_score                                       0.5
# split0_train_score                                        1
# split1_test_score                                  0.434783
# split1_train_score                                        1
# split2_test_score                                  0.545455
# split2_train_score                                        1
# split3_test_score                                       0.5
# split3_train_score                                        1
# split4_test_score                                  0.571429
# split4_train_score                                        1
# std_fit_time                                    0.000488772
# std_score_time                                  0.000398922
# std_test_score                                     0.046435
# std_train_score                                           0
#
#                                                             24  \
# mean_fit_time                                      0.000199461
# mean_score_time                                    0.000199652
# mean_test_score                                       0.928571
# mean_train_score                                      0.935325
# param_C                                                     10
# param_gamma                                              0.001
# param_kernel                                               rbf
# params              {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# rank_test_score                                             15
# split0_test_score                                        0.875
# split0_train_score                                    0.943182
# split1_test_score                                     0.913043
# split1_train_score                                     0.94382
# split2_test_score                                            1
# split2_train_score                                    0.922222
# split3_test_score                                     0.909091
# split3_train_score                                    0.933333
# split4_test_score                                     0.952381
# split4_train_score                                    0.934066
# std_fit_time                                       0.000398922
# std_score_time                                     0.000399303
# std_test_score                                       0.0429827
# std_train_score                                     0.00788839
#
#                                                            25  \
# mean_fit_time                                     0.000997162
# mean_score_time                                             0
# mean_test_score                                      0.964286
# mean_train_score                                     0.977676
# param_C                                                    10
# param_gamma                                              0.01
# param_kernel                                              rbf
# params              {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# rank_test_score                                             3
# split0_test_score                                           1
# split0_train_score                                   0.977273
# split1_test_score                                    0.956522
# split1_train_score                                   0.977528
# split2_test_score                                           1
# split2_train_score                                   0.966667
# split3_test_score                                    0.909091
# split3_train_score                                   0.988889
# split4_test_score                                    0.952381
# split4_train_score                                   0.978022
# std_fit_time                                      5.35248e-07
# std_score_time                                              0
# std_test_score                                      0.0340769
# std_train_score                                    0.00703191
#
#                                                           26  \
# mean_fit_time                                    0.000597477
# mean_score_time                                            0
# mean_test_score                                     0.964286
# mean_train_score                                    0.986566
# param_C                                                   10
# param_gamma                                              0.1
# param_kernel                                             rbf
# params              {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# rank_test_score                                            3
# split0_test_score                                   0.958333
# split0_train_score                                  0.988636
# split1_test_score                                   0.956522
# split1_train_score                                  0.977528
# split2_test_score                                          1
# split2_train_score                                  0.977778
# split3_test_score                                   0.954545
# split3_train_score                                  0.988889
# split4_test_score                                   0.952381
# split4_train_score                                         1
# std_fit_time                                     0.000487844
# std_score_time                                             0
# std_test_score                                     0.0177687
# std_train_score                                   0.00835549
#
#                                                         27  \
# mean_fit_time                                  0.000199318
# mean_score_time                                          0
# mean_test_score                                     0.9375
# mean_train_score                                  0.986591
# param_C                                                 10
# param_gamma                                              1
# param_kernel                                           rbf
# params              {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# rank_test_score                                         14
# split0_test_score                                 0.916667
# split0_train_score                                0.988636
# split1_test_score                                 0.956522
# split1_train_score                                0.977528
# split2_test_score                                        1
# split2_train_score                                0.977778
# split3_test_score                                 0.863636
# split3_train_score                                       1
# split4_test_score                                 0.952381
# split4_train_score                                0.989011
# std_fit_time                                   0.000398636
# std_score_time                                           0
# std_test_score                                   0.0452528
# std_train_score                                 0.00836242
#
#                                                          28  \
# mean_fit_time                                   0.000605774
# mean_score_time                                 0.000199556
# mean_test_score                                    0.919643
# mean_train_score                                          1
# param_C                                                  10
# param_gamma                                              10
# param_kernel                                            rbf
# params              {'C': 10, 'gamma': 10, 'kernel': 'rbf'}
# rank_test_score                                          17
# split0_test_score                                     0.875
# split0_train_score                                        1
# split1_test_score                                  0.956522
# split1_train_score                                        1
# split2_test_score                                         1
# split2_train_score                                        1
# split3_test_score                                  0.818182
# split3_train_score                                        1
# split4_test_score                                  0.952381
# split4_train_score                                        1
# std_fit_time                                    0.000494657
# std_score_time                                  0.000399113
# std_test_score                                    0.0647906
# std_train_score                                           0
#
#                                                           29  \
# mean_fit_time                                     0.00059886
# mean_score_time                                  0.000399065
# mean_test_score                                       0.5625
# mean_train_score                                           1
# param_C                                                   10
# param_gamma                                              100
# param_kernel                                             rbf
# params              {'C': 10, 'gamma': 100, 'kernel': 'rbf'}
# rank_test_score                                           24
# split0_test_score                                   0.541667
# split0_train_score                                         1
# split1_test_score                                   0.478261
# split1_train_score                                         1
# split2_test_score                                   0.590909
# split2_train_score                                         1
# split3_test_score                                   0.590909
# split3_train_score                                         1
# split4_test_score                                   0.619048
# split4_train_score                                         1
# std_fit_time                                     0.000488968
# std_score_time                                   0.000488753
# std_test_score                                     0.0496678
# std_train_score                                            0
#
#                                                              30  \
# mean_fit_time                                       0.000792265
# mean_score_time                                               0
# mean_test_score                                        0.964286
# mean_train_score                                       0.977676
# param_C                                                     100
# param_gamma                                               0.001
# param_kernel                                                rbf
# params              {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# rank_test_score                                               3
# split0_test_score                                             1
# split0_train_score                                     0.977273
# split1_test_score                                      0.956522
# split1_train_score                                     0.977528
# split2_test_score                                             1
# split2_train_score                                     0.966667
# split3_test_score                                      0.909091
# split3_train_score                                     0.988889
# split4_test_score                                      0.952381
# split4_train_score                                     0.978022
# std_fit_time                                        0.000396273
# std_score_time                                                0
# std_test_score                                        0.0340769
# std_train_score                                      0.00703191
#
#                                                             31  \
# mean_fit_time                                      0.000598335
# mean_score_time                                              0
# mean_test_score                                       0.973214
# mean_train_score                                      0.984368
# param_C                                                    100
# param_gamma                                               0.01
# param_kernel                                               rbf
# params              {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# rank_test_score                                              1
# split0_test_score                                            1
# split0_train_score                                    0.988636
# split1_test_score                                     0.956522
# split1_train_score                                    0.977528
# split2_test_score                                            1
# split2_train_score                                    0.977778
# split3_test_score                                     0.954545
# split3_train_score                                    0.988889
# split4_test_score                                     0.952381
# split4_train_score                                    0.989011
# std_fit_time                                       0.000488539
# std_score_time                                               0
# std_test_score                                       0.0223995
# std_train_score                                     0.00548507
#
#                                                            32  \
# mean_fit_time                                     0.000997448
# mean_score_time                                             0
# mean_test_score                                      0.955357
# mean_train_score                                     0.988788
# param_C                                                   100
# param_gamma                                               0.1
# param_kernel                                              rbf
# params              {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# rank_test_score                                             9
# split0_test_score                                    0.958333
# split0_train_score                                   0.988636
# split1_test_score                                           1
# split1_train_score                                   0.977528
# split2_test_score                                           1
# split2_train_score                                   0.977778
# split3_test_score                                    0.863636
# split3_train_score                                          1
# split4_test_score                                    0.952381
# split4_train_score                                          1
# std_fit_time                                      1.83195e-06
# std_score_time                                              0
# std_test_score                                      0.0495662
# std_train_score                                    0.00999451
#
#                                                          33  \
# mean_fit_time                                   0.000598431
# mean_score_time                                           0
# mean_test_score                                    0.946429
# mean_train_score                                          1
# param_C                                                 100
# param_gamma                                               1
# param_kernel                                            rbf
# params              {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# rank_test_score                                          11
# split0_test_score                                  0.916667
# split0_train_score                                        1
# split1_test_score                                         1
# split1_train_score                                        1
# split2_test_score                                         1
# split2_train_score                                        1
# split3_test_score                                  0.863636
# split3_train_score                                        1
# split4_test_score                                  0.952381
# split4_train_score                                        1
# std_fit_time                                    0.000488617
# std_score_time                                            0
# std_test_score                                    0.0519227
# std_train_score                                           0
#
#                                                           34  \
# mean_fit_time                                    0.000599241
# mean_score_time                                  0.000199461
# mean_test_score                                     0.919643
# mean_train_score                                           1
# param_C                                                  100
# param_gamma                                               10
# param_kernel                                             rbf
# params              {'C': 100, 'gamma': 10, 'kernel': 'rbf'}
# rank_test_score                                           17
# split0_test_score                                      0.875
# split0_train_score                                         1
# split1_test_score                                   0.956522
# split1_train_score                                         1
# split2_test_score                                          1
# split2_train_score                                         1
# split3_test_score                                   0.818182
# split3_train_score                                         1
# split4_test_score                                   0.952381
# split4_train_score                                         1
# std_fit_time                                      0.00048928
# std_score_time                                   0.000398922
# std_test_score                                     0.0647906
# std_train_score                                            0
#
#                                                            35  \
# mean_fit_time                                     0.000598383
# mean_score_time                                   0.000399351
# mean_test_score                                        0.5625
# mean_train_score                                            1
# param_C                                                   100
# param_gamma                                               100
# param_kernel                                              rbf
# params              {'C': 100, 'gamma': 100, 'kernel': 'rbf'}
# rank_test_score                                            24
# split0_test_score                                    0.541667
# split0_train_score                                          1
# split1_test_score                                    0.478261
# split1_train_score                                          1
# split2_test_score                                    0.590909
# split2_train_score                                          1
# split3_test_score                                    0.590909
# split3_train_score                                          1
# split4_test_score                                    0.619048
# split4_train_score                                          1
# std_fit_time                                      0.000488578
# std_score_time                                    0.000489105
# std_test_score                                      0.0496678
# std_train_score                                             0
#
#                                                   36  \
# mean_fit_time                            0.000592852
# mean_score_time                                    0
# mean_test_score                             0.366071
# mean_train_score                            0.366079
# param_C                                        0.001
# param_gamma                                      NaN
# param_kernel                                  linear
# params              {'C': 0.001, 'kernel': 'linear'}
# rank_test_score                                   27
# split0_test_score                              0.375
# split0_train_score                          0.363636
# split1_test_score                           0.347826
# split1_train_score                          0.370787
# split2_test_score                           0.363636
# split2_train_score                          0.366667
# split3_test_score                           0.363636
# split3_train_score                          0.366667
# split4_test_score                           0.380952
# split4_train_score                          0.362637
# std_fit_time                             0.000484164
# std_score_time                                     0
# std_test_score                             0.0113708
# std_train_score                           0.00285176
#
#                                                  37  \
# mean_fit_time                                     0
# mean_score_time                                   0
# mean_test_score                            0.848214
# mean_train_score                           0.855069
# param_C                                        0.01
# param_gamma                                     NaN
# param_kernel                                 linear
# params              {'C': 0.01, 'kernel': 'linear'}
# rank_test_score                                  21
# split0_test_score                          0.916667
# split0_train_score                         0.886364
# split1_test_score                          0.826087
# split1_train_score                          0.88764
# split2_test_score                          0.818182
# split2_train_score                         0.866667
# split3_test_score                          0.772727
# split3_train_score                         0.755556
# split4_test_score                          0.904762
# split4_train_score                         0.879121
# std_fit_time                                      0
# std_score_time                                    0
# std_test_score                            0.0547783
# std_train_score                           0.0503114
#
#                                                 38  \
# mean_fit_time                                    0
# mean_score_time                                  0
# mean_test_score                           0.946429
# mean_train_score                          0.966538
# param_C                                        0.1
# param_gamma                                    NaN
# param_kernel                                linear
# params              {'C': 0.1, 'kernel': 'linear'}
# rank_test_score                                 11
# split0_test_score                         0.958333
# split0_train_score                        0.965909
# split1_test_score                         0.913043
# split1_train_score                        0.977528
# split2_test_score                                1
# split2_train_score                        0.944444
# split3_test_score                         0.909091
# split3_train_score                        0.977778
# split4_test_score                         0.952381
# split4_train_score                        0.967033
# std_fit_time                                     0
# std_score_time                                   0
# std_test_score                           0.0332185
# std_train_score                          0.0121316
#
#                                               39  \
# mean_fit_time                                  0
# mean_score_time                                0
# mean_test_score                         0.973214
# mean_train_score                        0.984368
# param_C                                        1
# param_gamma                                  NaN
# param_kernel                              linear
# params              {'C': 1, 'kernel': 'linear'}
# rank_test_score                                1
# split0_test_score                              1
# split0_train_score                      0.988636
# split1_test_score                       0.956522
# split1_train_score                      0.977528
# split2_test_score                              1
# split2_train_score                      0.977778
# split3_test_score                       0.954545
# split3_train_score                      0.988889
# split4_test_score                       0.952381
# split4_train_score                      0.989011
# std_fit_time                                   0
# std_score_time                                 0
# std_test_score                         0.0223995
# std_train_score                       0.00548507
#
#                                                40  \
# mean_fit_time                         0.000598621
# mean_score_time                                 0
# mean_test_score                          0.964286
# mean_train_score                         0.988813
# param_C                                        10
# param_gamma                                   NaN
# param_kernel                               linear
# params              {'C': 10, 'kernel': 'linear'}
# rank_test_score                                 3
# split0_test_score                        0.958333
# split0_train_score                       0.988636
# split1_test_score                               1
# split1_train_score                       0.988764
# split2_test_score                               1
# split2_train_score                       0.977778
# split3_test_score                        0.909091
# split3_train_score                       0.988889
# split4_test_score                        0.952381
# split4_train_score                              1
# std_fit_time                          0.000488772
# std_score_time                                  0
# std_test_score                          0.0338387
# std_train_score                        0.00702801
#
#                                                 41
# mean_fit_time                          0.000199652
# mean_score_time                        0.000598192
# mean_test_score                           0.964286
# mean_train_score                          0.993258
# param_C                                        100
# param_gamma                                    NaN
# param_kernel                                linear
# params              {'C': 100, 'kernel': 'linear'}
# rank_test_score                                  3
# split0_test_score                         0.958333
# split0_train_score                        0.988636
# split1_test_score                                1
# split1_train_score                        0.988764
# split2_test_score                                1
# split2_train_score                        0.988889
# split3_test_score                         0.909091
# split3_train_score                               1
# split4_test_score                         0.952381
# split4_train_score                               1
# std_fit_time                           0.000399303
# std_score_time                         0.000488422
# std_test_score                           0.0338387
# std_train_score                         0.00550551

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
scores = cross_val_score(GridSearchCV(SVC(), param_grid, cv=5),
                         iris.data, iris.target, cv=5)
print("교차 검증 점수: ", scores)
print("교차 검증 평균 점수: ", scores.mean())
print(param_grid)
# Out:
# 교차 검증 점수:  [0.96666667 1.         0.96666667 0.96666667 1.        ]
# 교차 검증 평균 점수:  0.9800000000000001
# {'C': [0.001, 0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}

# %%
def nested_cv(X, y, inner_cv, outer_cv, Classifier, parameter_grid):
    outer_scores = []
    # outer_cv의 분할을 순회하는 for 루프
    # (split 메소드는 훈련과 테스트 세트에 해당하는 인덱스를 리턴합니다)
    for training_samples, test_samples in outer_cv.split(X, y):
        # 최적의 매개변수를 찾습니다
        best_parms = {}
        best_score = -np.inf
        # 매개변수 그리드를 순회합니다
        for parameters in parameter_grid:
            # 안쪽 교차 검증의 점수를 기록합니다
            cv_scores = []
            # inner_cv의 분할을 순회하는 for 루프
            for inner_train, inner_test in inner_cv.split(
                    X[training_samples], y[training_samples]):
                # 훈련 데이터와 주어진 매개변수로 분류기를 만듭니다
                clf = Classifier(**parameters)
                clf.fit(X[inner_train], y[inner_train])
                # 검증 세트로 평가합니다
                score = clf.score(X[inner_test], y[inner_test])
                cv_scores.append(score)
            # 안쪽 교차 검증의 평균 점수를 계산합니다
            mean_score = np.mean(cv_scores)
            if mean_score > best_score:
                # 점수가 더 높은면 매개변수와 함께 기록합니다
                best_score = mean_score
                best_params = parameters
        # 바깥쪽 훈련 데이터 전체를 사용해 분류기를 만듭니다
        clf = Classifier(**best_params)
        clf.fit(X[training_samples], y[training_samples])
        # 테스트 세트를 사용해 평가합니다
        outer_scores.append(clf.score(X[test_samples], y[test_samples]))
    return np.array(outer_scores)

# %%
from sklearn.model_selection import ParameterGrid, StratifiedKFold
scores = nested_cv(iris.data, iris.target, StratifiedKFold(5),
                   StratifiedKFold(5), SVC, ParameterGrid(param_grid))
print("교차 검증 점수: {}".format(scores))
# Out:
# 교차 검증 점수: [0.96666667 1.         0.96666667 0.96666667 1.        ]
