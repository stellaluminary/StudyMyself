# %%
from sklearn.datasets import load_iris
import numpy as np
import matplotlib.pyplot as plt
iris=load_iris()

# %%
average=np.mean(iris.data, axis=0)
std=np.std(iris.data, axis=0)
range_ = range(np.shape(iris.data)[1])
print(range_)
np.shape(iris.data),np.shape(iris.data)[1]
# Out:
# range(0, 4)
# ((150, 4), 4)

# %%
plt.subplot(1,2,1)
plt.title("Horizontal bars")
plt.barh(range_, average, color='r', xerr=std, alpha=0.4, align="center")
plt.yticks(range_,iris.feature_names)
plt.subplot(1,2,2)
plt.title("Vertical bars")
plt.bar(range_, average, color='b', yerr=std, alpha=0.4, align="center")
plt.yticks(range_,range_)
plt.show()

# %%
from sklearn.datasets import fetch_olivetti_faces
import numpy as np
datasets=fetch_olivetti_faces(shuffle=True, random_state=5)
photo=1
for k in range(6):
    plt.subplot(2,3,k+1)
    plt.imshow(datasets.data[k].reshape(64,64), cmap=plt.cm.gray, interpolation='nearest')
    plt.title('subject '+ str(datasets.target[k]))
    plt.axis('off')
plt.show()

# %%
np.shape(datasets.data[k])
# Out:
# (4096,)

# %%
plt.imshow(datasets.data[2].reshape(-1,64), interpolation='nearest')

# %%
plt.imshow(datasets.data[2].reshape(-1,64))

# %%
from sklearn.datasets import load_digits
digits=load_digits()
for number in range(1, 10):
    plt.subplot(3,4,number)
    plt.imshow(digits.images[number],cmap='binary', interpolation='none',extent=[0, 10,0, 10])
    plt.grid()
plt.show()

# %%
plt.imshow(digits.images[0],cmap='binary', interpolation='none',extent=[0, 10,0, 10])
plt.grid()
plt.show()
