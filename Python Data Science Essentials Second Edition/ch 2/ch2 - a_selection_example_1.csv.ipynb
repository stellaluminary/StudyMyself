# %%
import pandas as pd

# %%
dataset=pd.read_csv('C:\\Users\\la\\Desktop\\PythonDataScienceEssentialsSecondEdition_Code\\Chapter 2\\code\\a_selection_example_1.csv',index_col=0)
dataset
# Out:
#      val1  val2 val3
# n
# 100    10    10    C
# 101    10    20    C
# 102    10    30    B
# 103    10    40    B
# 104    10    50    A

# %%
dataset['val3'][104]
# Out:
# 'A'

# %%
dataset.loc[104,'val3']
# Out:
# 'A'

# %%
dataset.ix[104,2]
# Out:
# 'A'

# %%
dataset.iloc[4,2]
# Out:
# 'A'

# %%
dataset[['val3','val2']][0:2]
# Out:
#     val3  val2
# n
# 100    C    10
# 101    C    20

# %%
dataset.loc[range(100,102),['val3','val2']]
# Out:
#     val3  val2
# n
# 100    C    10
# 101    C    20

# %%
dataset.ix[range(100,102),['val3','val2']]
# Out:
#     val3  val2
# n
# 100    C    10
# 101    C    20

# %%
dataset.iloc[range(2),[2,1]]
# Out:
#     val3  val2
# n
# 100    C    10
# 101    C    20
